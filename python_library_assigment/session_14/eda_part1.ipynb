# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Q1
df=pd.read_csv(r"c:\Users\Divyansh yadav\Desktop\python_library\ipl_matches.csv")

print(df["total_runs"].describe())
# Out:
# count    200.00000
# mean     162.59500
# std       22.70437
# min      110.00000
# 25%      146.75000
# 50%      162.00000
# 75%      177.25000
# max      230.00000
# Name: total_runs, dtype: float64

# %%
# Q2
df1=pd.read_csv(r"C:\Users\Divyansh yadav\Desktop\python_library\flipkart_reviews (1).csv")

df1

sns.countplot(data=df1,x="rating")
plt.title("Count of Reviews by Rating")
plt.xlabel("Rating (Stars)")
plt.ylabel("Number of Reviews")
# Out:
# Text(0, 0.5, 'Number of Reviews')

# %%
# Q3
df2=pd.read_csv(r"C:\Users\Divyansh yadav\Desktop\python_library\zomato_listings.csv")
df2
sns.scatterplot(data=df2,x="average_cost_for_two",y="user_rating")
plt.title("Relationship Between Cost for Two and User Rating")
plt.xlabel("Average Cost for Two (₹)")
plt.ylabel("User Rating")
# Out:
# Text(0, 0.5, 'User Rating')

# %%
# Q4
df3=pd.read_csv(r"C:\Users\Divyansh yadav\Desktop\python_library\bookmyshow_movies.csv")


print(
    df3.groupby("genre")
       .agg(avg_of_box_office_collection=("box_office_collection", "mean"))
       .sort_values(by="avg_of_box_office_collection", ascending=True)
)
# Out:
#            avg_of_box_office_collection
# genre
# Horror                        73.937333
# Biography                     80.756216
# Drama                         92.364603
# Romance                       95.178333
# Comedy                       118.584634
# Thriller                     146.448421
# Adventure                    181.178846
# Animation                    188.702500
# Action                       231.520847
# Sci-Fi                       261.849737

# %%
# Q5
df4=pd.read_csv(r"C:\Users\Divyansh yadav\Desktop\python_library\spotify_songs.csv")

sns.pairplot(df4[["danceability","energy","valence","popularity"]])
